# %% [markdown]
# <a href="https://colab.research.google.com/github/Harsh-al10/DV-lab-expirements/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt


months = ["Jan", "Feb", "Mar", "Apr", "May"]
sales = [150, 200, 180, 220, 250]

# %%
plt.figure()
plt.bar(months, sales)
plt.title("Monthly Sales - Bar Chart")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure()
plt.plot(months, sales, marker='o')
plt.title("Monthly Sales - Line Chart")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.show()

# %%
plt.figure()
plt.pie(sales, labels=months, autopct='%1.1f%%')
plt.title("Monthly Sales - Pie Chart")
plt.show()
